# %%
from bitcoin_parser import *
from datetime import datetime
import json
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (15,6)

file_blocks = r"blocks.json"
file_trans = r"txs.json"


print("Finding the number of transactions per block:")
print("")
count_transacions(file_blocks)
;
# Out:
# Finding the number of transactions per block:
# ''

# %%
print("Finding the value of each transaction on each block:")
print("")
value_block(file_blocks, file_trans)
;
# Out:
# Finding the value of each transaction on each block:
# ''

# %%
print("Calculating the time interval between blocks")
print("")
timedelta_bloques(file_blocks)
;
# Out:
# Calculating the time interval between blocks
# ''

# %%
print("Calculating the average size of the block per hour")
print("")
avg_size_block(file_blocks)
;
# Out:
# Calculating the average size of the block per hour
# ''

# %%
print("Obtaining the number of transactions per hour.")
print("")
count_tr_block(file_blocks)
# Out:
# Obtaining the number of transactions per hour.
# <BarContainer object of 27 artists>
